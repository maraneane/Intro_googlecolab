# %% [markdown]
# <a href="https://colab.research.google.com/github/maraneane/maranepassos/blob/main/Introdu%C3%A7%C3%A3o_do_Google_Colab_e_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução do Google Colab
#
# - O **Google Colab** é uma solução do Google para rodar no sistema de computação em nuvem do Google, notebooks em Python.
# - Notebooks são maneiras interativas de executar código.
# - Em um notebook, a cada bloco de código executado, o resultado é exibido na tela.
# - O usuário controla o momento e a order que os blocos (**células**) serão executados.

# %% [markdown]
# ### Executando código
#
# O exemplo abaixo cria uma variável (número), soma 2 a esse número e mostra na o resultado.
#
# Para executar o código bastar clicar no botão de "**play**" ao ladoda célula.

# %%
variavel = 5
variavel += 2
variavel
# Out:
# 7

# %% [markdown]
# Alternativamente, para executar uma célula basta pressionar `Shift+Enter`.

# %%
variavel = 9
variavel += 3
variavel
# Out:
# 12

# %% [markdown]
# ### A ordem em que o código é executado, importa.
#
# Tentar executar o código abaixo na ordem como está apresentada vai resultar em um erro.

# %%
b = 4

# %%
a = b * 3
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-17ce4021a5cd> in <module>()
# ----> 1 a = b * 3
#       2 a
#
# NameError: name 'b' is not defined

# %% [markdown]
# ### Um notebook no Colab é uma "máquina virtual"
#
# - Ela roda sistema operacional Ubuntu.
# - Tem memoria e armazenamentos limitados.
# - É possivel executar comando nessa máquina e até instalar outros softwares.

# %%
# Lista os arquivos e o caminho do diretório atual.
# !ls
# !pwd
# Out:
# dummy_file.md  dummy_file.md.1	sample_data
# /content

# %%
# Instala o VIM
# !apt install -y vim
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# vim is already the newest version (2:8.0.1453-1ubuntu1.4).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %% [markdown]
# ### Arquivos locais
#
# - Na barra de menu à esquerda, é possível navegar pelos arquivos disponíveis.
# - Se a célula abaixo for executada, o arquivo `dummy_file.md` deve ter sido baixado.

# %%
# Baixa um arquivo para o sistema local.
# !wget https://gist.githubusercontent.com/ftorresd/fda52c01300491570dff4deef0f1019a/raw/0ffe0a21f6aeddcb2419426a82c8a3b6ed8b203b/dummy_file.md
# Out:
# --2021-07-26 21:54:17--  https://gist.githubusercontent.com/ftorresd/fda52c01300491570dff4deef0f1019a/raw/0ffe0a21f6aeddcb2419426a82c8a3b6ed8b203b/dummy_file.md
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12 [text/plain]
# Saving to: ‘dummy_file.md.1’
#
# dummy_file.md.1     100%[===================>]      12  --.-KB/s    in 0s
#
# 2021-07-26 21:54:17 (774 KB/s) - ‘dummy_file.md.1’ saved [12/12]

# %% [markdown]
# ### Bibliotecas via pip
#
# - Bibliotecas para Python podem ser instaladas via `pip`.
# - A lógica é a mesma de executar um comando diretamente no sistema operacional.

# %%
# !pip install uproot

# %% [markdown]
# Agora podemos utilizar a biblioteca instalada.

# %%
import uproot
uproot
# Out:
# <module 'uproot' from '/usr/local/lib/python3.7/dist-packages/uproot/__init__.py'>

# %% [markdown]
# ### Algumas células podem estar ocultas
#
# - Para revelar as células, bas ta clicar no símbolo de ">", ao lado.

# %% [markdown]
# Essa célula não é mais oculta.

# %% [markdown]
# ### Células de Texto x Código
#
# - Células podem ser de texto ou código.
# - Células de código são formatadas em [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet).
# - Menu `Inserir >> Célula de Texto` insere, abaixo da célula atual, uma célula de texto.
# - Um duplo clique numa célula de texto abre o modo de edição.

# %% [markdown]
# *Me edite!!!*

# %% [markdown]
# ### Gráficos, imagens, tabelas...
#
# - O grande poder de um  notebook é a possibilidade de produzir gráficos, imagens, tabelas ou outras tipos suportados, e  visualiza-los, ou editá-los, interativamente.

# %%
# Um gráfico

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y);

# %%
# Uma imagem
import matplotlib.cbook as cbook


with cbook.get_sample_data('grace_hopper.png') as image_file:
    image = plt.imread(image_file)

plt.imshow(image);

# %%
# Uma tabela no Pandas
import pandas as pd
pd.DataFrame({'A': 1., 'B': pd.Timestamp('20130102'), 'C': pd.Series(1, index=list(range(4)), dtype='float32'), 'D': np.array([3] * 4, dtype='int32'), 'E': pd.Categorical(["test", "train", "test", "train"]), 'F': 'foo'})
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
